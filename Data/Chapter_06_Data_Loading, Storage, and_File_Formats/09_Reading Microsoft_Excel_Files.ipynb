# %% [markdown]
# # Reading Microsoft Excel Files
#
# pandas also supports reading tabular data stored in Excel 2003 (and higher) files using the ExcelFile class. Interally ExcelFile uses the xlrd and openpyxl packages, so you may have to install them first. To use ExcelFile, create an instance by passing a path to an xls or xlsx file:

# %%
import pandas as pd
from lxml.html import parse

# %%
pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\mbkmu\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.0.1)Note: you may need to restart the kernel to use updated packages.

# %%
xls_file = pd.ExcelFile('../../CSV Files/data.xls')

# %%
xls_file

# %% [markdown]
# Data stored in a sheet can then be read into DataFrame using parse:

# %%
table = xls_file.parse()

table

# table = xls_file.parse('Sheet1')
# Out:
#     Domain Code           Domain  Area Code      Area  Element Code  \
# 0           RFN  Fertilizers by         165  Pakistan          5157
# 1           RFN  Fertilizers by         165  Pakistan          5157
# 2           RFN  Fertilizers by         165  Pakistan          5157
# 3           RFN  Fertilizers by         165  Pakistan          5157
# 4           RFN  Fertilizers by         165  Pakistan          5157
# ..          ...              ...        ...       ...           ...
# 167         RFN  Fertilizers by         165  Pakistan          5157
# 168         RFN  Fertilizers by         165  Pakistan          5157
# 169         RFN  Fertilizers by         165  Pakistan          5157
# 170         RFN  Fertilizers by         165  Pakistan          5157
# 171         RFN  Fertilizers by         165  Pakistan          5157
#
#               Element  Item Code                     Item  Year Code  Year  \
# 0    Agricultural Use       3102       nitrogen N (total)       1961  1961
# 1    Agricultural Use       3103   phosphate P2O5 (total)       1961  1961
# 2    Agricultural Use       3103   phosphate P2O5 (total)       1962  1962
# 3    Agricultural Use       3102       nitrogen N (total)       1962  1962
# 4    Agricultural Use       3102       nitrogen N (total)       1963  1963
# ..                ...        ...                      ...        ...   ...
# 167  Agricultural Use       3102       nitrogen N (total)       2018  2018
# 168  Agricultural Use       3104       potash K2O (total)       2018  2018
# 169  Agricultural Use       3104       potash K2O (total)       2019  2019
# 170  Agricultural Use       3102       nitrogen N (total)       2019  2019
# 171  Agricultural Use       3103   phosphate P2O5 (total)       2019  2019
#
#        Unit    Value Flag                                   Flag Description
# 0    tonnes    41659   Qm  Official data from questionnaires and/or natio...
# 1    tonnes      500   Qm  Official data from questionnaires and/or natio...
# 2    tonnes      210   Qm  Official data from questionnaires and/or natio...
# 3    tonnes    41160   Qm  Official data from questionnaires and/or natio...
# 4    tonnes    67620   Qm  Official data from questionnaires and/or natio...
# ..      ...      ...  ...                                                ...
# 167  tonnes  3446922   Fm                                  Manual Estimation
# 168  tonnes    54173   Fm                                  Manual Estimation
# 169  tonnes    47260   Qm  Official data from questionnaires and/or natio...
# 170  tonnes  3505356   Qm  Official data from questionnaires and/or natio...
# 171  tonnes  1099707   Qm  Official data from questionnaires and/or natio...
#
# [172 rows x 14 columns]
